# %%
import sys
from nyoka import PMML43Ext as ny
ny.__file__
# Out:
# '/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/nyoka/pmml/PMML43Ext.py'

# %% [markdown]
# # Nyoka - Gaussian Distribution issue

# %%
gb = ny.TargetValueStat(0,GaussianDistribution=ny.GaussianDistribution(mean=0.3,variance=2.5))
gb.export(sys.stdout,0,'')
# Out:
# <TargetValueStat value="0">
#     <GaussianDistribution mean="0.3" variance="2.5"/>
# </TargetValueStat>

# %% [markdown]
# # Nyoka - MapValues issue

# %%
row_main = ny.row()
row_short = ny.row()
row_short.original_tagname_ = 'input'
row_long = ny.row('M')     #row cannot export any str,int,float 
row_long.original_tagname_ = 'output'
row_main.add_anytypeobjs_(row_short)
row_main.add_anytypeobjs_(row_long)
row_main.export(sys.stdout,0,'')
# Out:
# <row>
#     <input
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-f19d34fc64e1> in <module>()
#       6 row_main.add_anytypeobjs_(row_short)
#       7 row_main.add_anytypeobjs_(row_long)
# ----> 8 row_main.export(sys.stdout,0,'')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/nyoka/pmml/PMML43ExtSuper.py in export(self, outfile, level, namespace_, name_, namespacedef_, pretty_print)
#   51619         if self.hasContent_():
#   51620             outfile.write('>%s' % (eol_, ))
# > 51621             self.exportChildren(outfile, level + 1, namespace_='', name_='row', pretty_print=pretty_print)
#   51622             showIndent(outfile, level, pretty_print)
#   51623             outfile.write('</%s%s>%s' % (namespace_, name_, eol_))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/nyoka/pmml/PMML43ExtSuper.py in exportChildren(self, outfile, level, namespace_, name_, fromsubclass_, pretty_print)
#   51634             # print("printing: " + str(obj_))
#   51635             try:
# > 51636                 obj_.export(outfile, level, namespace_, pretty_print=pretty_print)
#   51637             except:
#   51638                 raise
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/nyoka/pmml/PMML43ExtSuper.py in export(self, outfile, level, namespace_, name_, namespacedef_, pretty_print)
#   51617         already_processed = set()
#   51618         self.exportAttributes(outfile, level, already_processed, namespace_, name_='row')
# > 51619         if self.hasContent_():
#   51620             outfile.write('>%s' % (eol_, ))
#   51621             self.exportChildren(outfile, level + 1, namespace_='', name_='row', pretty_print=pretty_print)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/nyoka/pmml/PMML43ExtSuper.py in hasContent_(self)
#   51598     def hasContent_(self):
#   51599         if (
# > 51600             self.anytypeobjs_ or self.elementobjs_
#   51601         ):
#   51602             return True
#
# AttributeError: 'row' object has no attribute 'elementobjs_'

# %%
map_val = ny.MapValues(FieldColumnPair=[ny.FieldColumnPair(field='gender',column='input')],outputColumn='output',InlineTable=ny.InlineTable(row=[row_main]))
der_field = ny.DerivedField(name="label_encoder(gender)",optype='categorical',dataType='string',MapValues=map_val)

der_field.export(sys.stdout,0,'')
